# %%
# !pip install nibabel
# Out:
# ...
#     100% |████████████████████████████████| 3.3MB 6.5MB/s ta 0:00:011
# ...

# %%
# !pip install torch
# Out:
# ...
#     100% |████████████████████████████████| 81.1MB 428kB/s ta 0:00:011
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt
import nibabel as nib
import torch as pt

# %%
image_T1 = nib.load("IXI267-HH-1772-T1_fcm.nii.gz")
image_T1_data = image_T1.get_fdata()

# %%
image_T2 = nib.load("IXI267-HH-1772-T2_reg_fcm.nii.gz")
image_T2_data = image_T2.get_fdata()

# %%
plt.gray()

# %%
image_T1_data.shape
# Out:
# (240, 240, 180)

# %%
image_T2_data.shape
# Out:
# (240, 240, 180)

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
imgplot = plt.imshow(image_T1_data[:, :, 60])

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
imgplot = plt.imshow(image_T2_data[:, :, 60])
